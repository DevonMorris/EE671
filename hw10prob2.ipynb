# %% [markdown]
# a)

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x_1 = np.linspace(-5,5, num = 10000)
x_2 = x_1**2

plt.plot(x_1,x_2)
plt.axis('equal')
plt.show()

# %% [markdown]
# b)
# Our $x(\xi)$ is obviously given by
# $$ x(\xi) = (\xi, \xi^2)$$
# c) Note that
# $$ \frac{dx}{d\xi}(2) = (1, 4)$$
# and
# $$ \nabla h(2,4) = (4, -1)$$

# %%
V = np.array([[1,4],[4,-1]])
origin = [2], [4] # origin point

plt.plot(x_1,x_2)
plt.axis('equal')
plt.quiver(*origin, V[:,0], V[:,1], color=['r','b','g'], scale=21)
plt.show()
